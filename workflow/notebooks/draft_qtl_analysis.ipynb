# %% [markdown]
# ## Run a basic eqtl analysis
# This will be something to compare the PC results to
#
# do with and without residualized expression

# %%
import pandas as pd
import torch
import tensorqtl
from tensorqtl import pgen, cis, trans, post, genotypeio
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import numpy as np

tissue_id = 'Whole_Blood'
chr_id = '21'
e_out_prefix=f'/home/klawren/oak/pcqtl/output/test/{tissue_id}/{tissue_id}'
# Out:
# Warning: The R output will not be colorized because it seems that your terminal does not support ANSI escape codes. isatty(stdout()) returned FALSE.

# %% [markdown]
# ### load in data

# %%
# define paths to data

subsample_num =75

plink_prefix_path = '/home/klawren/oak/pcqtls/data/processed/genotypes/GTEx_Analysis_2017-06-05_v8_WholeGenomeSeq_838Indiv_Analysis_Freeze.SHAPEIT2_phased.MAF01'
pc_bed = f'/home/klawren/oak/pcqtls/output/subsampling_constant_clusters/{subsample_num}/pcs/{tissue_id}.pcs.bed'
covariates_file = f'/home/klawren/oak/pcqtls/data/processed/subsampling/{subsample_num}/covariates/{tissue_id}.v8.covariates.txt'

# load phenotypes and covariates
phenotype_df, phenotype_pos_df = tensorqtl.read_phenotype_bed(pc_bed)
covariates_df = pd.read_csv(covariates_file, sep='\t', index_col=0).T

# %%
# PLINK reader for genotypes
pgr = genotypeio.PlinkReader(plink_prefix_path)
genotype_df = pgr.load_genotypes()
variant_df = pgr.bim.set_index('snp')[['chrom', 'pos']]
# Out:
# Mapping files: 100%|██████████████████████████████| 3/3 [00:21<00:00,  7.04s/it]

# %% [markdown]
# # subsampling
# find a way to subset the cis results so I only map cis independent with the pc1 phenotypes

# %%
cis_output = f'/home/klawren/oak/pcqtls/output/subsampling_constant_clusters/{subsample_num}/pcqtl/{tissue_id}/{tissue_id}.v8.pcs.cis_qtl.txt.gz'

# %%
# load in cis results
cis_df = pd.read_csv(cis_output, sep='\t', index_col=0)
cis_df_pc1 = cis_df.copy()
cis_df_pc1['qval_old'] = cis_df_pc1['qval']
cis_df_pc1 = cis_df_pc1[cis_df_pc1.index.str.contains('pc1')]

# get qvalues for just the pc1s subsample
tensorqtl.calculate_qvalues(cis_df_pc1, qvalue_lambda=0.85)
# Out:
# Computing q-values
#   * Number of phenotypes tested: 886
#   * Correlation between Beta-approximated and empirical p-values: 0.9998
#   * Calculating q-values with lambda = 0.850
#   * Proportion of significant phenotypes (1-pi0): 0.28
#   * QTL phenotypes @ FDR 0.05: 0

# %%
# plot q values
ax = sns.scatterplot(cis_df_pc1, x='qval_old', y='qval')
axlim = ax.get_xlim()
ax.set_ylim(axlim)
ax.plot(axlim, axlim, color='red', linestyle='--')
ax.set_ylabel('qval pc1 only')
ax.set_xlabel('qval all pcs')
# Out:
# Text(0.5, 0, 'qval all pcs')

# %%
cis_df['qval_old'] = cis_df['qval']
tensorqtl.calculate_qvalues(cis_df, qvalue_lambda=0.85)
# Out:
# Computing q-values
#   * Number of phenotypes tested: 1977
#   * Correlation between Beta-approximated and empirical p-values: 0.9999
#   * Calculating q-values with lambda = 0.850
#   * Proportion of significant phenotypes (1-pi0): 0.28
#   * QTL phenotypes @ FDR 0.05: 75
#   * min p-value threshold @ FDR 0.05: 0.00255851

# %%
ax = sns.scatterplot(cis_df, x='qval_old', y='qval')

# plot q values
axlim = ax.get_xlim()
ax.set_ylim(axlim)
ax.plot(axlim, axlim, color='red', linestyle='--')
ax.set_ylabel('qval recalc')
ax.set_xlabel('qval old')
# Out:
# Text(0.5, 0, 'qval old')

# %%
indep_df_pc1 = cis.map_independent(genotype_df, variant_df, cis_df,
                               phenotype_df, phenotype_pos_df, covariates_df, maf_threshold = .01)
# Out:
# cis-QTL mapping: conditionally independent variants
#   * 100 samples
#   * 75/1977 significant phenotypes
#   * 68 covariates
#   * 10770860 variants
#   * applying in-sample 0.01 MAF filter
#   * cis-window: ±1,000,000
#   * checking phenotypes: 75/75
#   * computing independent QTLs
#     processing phenotype 75/75
#   Time elapsed: 0.76 min
# done.

# %%
indep_df_pc1
# Out:
#                                          phenotype_id  num_var  beta_shape1  \
# 0           ENSG00000011021.21_ENSG00000177000.10_pc1     7528      1.02539
# 1   ENSG00000083444.16_ENSG00000116685.15_ENSG0000...     7956      1.02453
# 2            ENSG00000183386.9_ENSG00000183431.11_pc1     6660      1.01822
# 3           ENSG00000117480.15_ENSG00000117481.10_pc1     5821      1.00798
# 4   ENSG00000160781.15_ENSG00000163472.18_ENSG0000...     5525      1.05451
# ..                                                ...      ...          ...
# 70          ENSG00000106772.17_ENSG00000187210.12_pc1     9842      1.05721
# 71           ENSG00000106804.7_ENSG00000119397.16_pc1     5765      1.01279
# 72          ENSG00000095321.16_ENSG00000119383.19_pc1     6663      1.01419
# 73          ENSG00000136816.15_ENSG00000136827.11_pc1     7867      1.03160
# 74           ENSG00000148296.6_ENSG00000148297.15_pc1     9211      1.05068
#
#     beta_shape2    true_df  pval_true_df              variant_id  \
# 0    836.356018  25.942499  2.309540e-07   chr1_11775398_T_G_b38
# 1    916.125000  26.494600  3.569540e-07   chr1_12008884_T_C_b38
# 2    815.814026  26.199400  5.989100e-07   chr1_37957563_C_A_b38
# 3    360.489014  25.926001  1.515300e-06   chr1_46340570_G_T_b38
# 4    500.667999  25.673800  1.027350e-09  chr1_156274030_C_T_b38
# ..          ...        ...           ...                     ...
# 70  1247.880005  26.118700  1.079060e-10  chr9_76713488_TG_T_b38
# 71   492.455994  26.125799  5.121330e-06  chr9_121057467_A_C_b38
# 72   769.825989  26.290899  7.234550e-08  chr9_129132061_A_C_b38
# 73  1008.059998  26.258101  9.553980e-07  chr9_129816670_G_A_b38
# 74  1226.280029  26.398399  1.012320e-09  chr9_133328538_A_G_b38
#
#     start_distance  end_distance  ma_samples  ma_count     af  pval_nominal  \
# 0           -31522        -31733          25        28  0.140  2.562980e-08
# 1            82456        -10582          60        70  0.650  5.881850e-08
# 2           -33358        -48043          27        30  0.150  8.928150e-08
# 3              393        -53695          44        49  0.245  2.224380e-07
# 4            25913        -21659          77        97  0.515  3.906530e-11
# ..             ...           ...         ...       ...    ...           ...
# 70          293638       -192599          34        38  0.190  4.332870e-12
# 71            7191        -17396          59        76  0.380  9.992820e-07
# 72           21111         20872          48        56  0.720  8.475800e-09
# 73           13517         -7464          22        23  0.115  1.572250e-07
# 74           -7860        -19593          53        66  0.330  7.159920e-11
#
#        slope  slope_se  pval_perm     pval_beta  rank
# 0   0.251938  0.033759     0.0002  1.537490e-04     1
# 1   0.227727  0.031840     0.0004  2.657090e-04     1
# 2  -0.249172  0.035608     0.0003  4.218170e-04     1
# 3  -0.263364  0.039529     0.0005  5.125790e-04     1
# 4   0.262378  0.026061     0.0001  2.280810e-07     1
# ..       ...       ...        ...           ...   ...
# 70  0.232538  0.021060     0.0001  5.311140e-08     1
# 71 -0.184267  0.030112     0.0022  2.320560e-03     1
# 72 -0.228758  0.029017     0.0002  4.817430e-05     1
# 73  0.312845  0.046078     0.0005  7.624510e-04     1
# 74 -0.222933  0.022728     0.0001  6.094420e-07     1
#
# [75 rows x 18 columns]

# %%
test_path = '/home/klawren/oak/pcqtls/output/testqtl.txt.gz'

# %%
indep_df = pd.read_csv('/home/klawren/oak/pcqtls/output/subsampling_constant_clusters/100/pcqtl/Whole_Blood/Whole_Blood.v8.pcs.cis_independent_qtl.txt.gz', sep='\t')
indep_df
# Out:
#                                          phenotype_id  num_var  beta_shape1  \
# 0           ENSG00000011021.21_ENSG00000177000.10_pc1     7528      1.02539
# 1   ENSG00000083444.16_ENSG00000116685.15_ENSG0000...     7956      1.02453
# 2            ENSG00000183386.9_ENSG00000183431.11_pc1     6660      1.01822
# 3           ENSG00000117480.15_ENSG00000117481.10_pc1     5821      1.00798
# 4   ENSG00000160781.15_ENSG00000163472.18_ENSG0000...     5525      1.05451
# ..                                                ...      ...          ...
# 73          ENSG00000106772.17_ENSG00000187210.12_pc1     9842      1.05721
# 74           ENSG00000106804.7_ENSG00000119397.16_pc1     5765      1.01279
# 75          ENSG00000095321.16_ENSG00000119383.19_pc1     6663      1.01419
# 76          ENSG00000136816.15_ENSG00000136827.11_pc1     7867      1.03160
# 77           ENSG00000148296.6_ENSG00000148297.15_pc1     9211      1.05068
#
#     beta_shape2  true_df  pval_true_df              variant_id  \
# 0       836.356  25.9425  2.309540e-07   chr1_11775398_T_G_b38
# 1       916.125  26.4946  3.569540e-07   chr1_12008884_T_C_b38
# 2       815.814  26.1994  5.989100e-07   chr1_37957563_C_A_b38
# 3       360.489  25.9260  1.515300e-06   chr1_46340570_G_T_b38
# 4       500.668  25.6738  1.027350e-09  chr1_156274030_C_T_b38
# ..          ...      ...           ...                     ...
# 73     1247.880  26.1187  1.079060e-10  chr9_76713488_TG_T_b38
# 74      492.456  26.1258  5.121330e-06  chr9_121057467_A_C_b38
# 75      769.826  26.2909  7.234550e-08  chr9_129132061_A_C_b38
# 76     1008.060  26.2581  9.553980e-07  chr9_129816670_G_A_b38
# 77     1226.280  26.3984  1.012320e-09  chr9_133328538_A_G_b38
#
#     start_distance  end_distance  ma_samples  ma_count     af  pval_nominal  \
# 0           -31522        -31733          25        28  0.140  2.562980e-08
# 1            82456        -10582          60        70  0.650  5.881850e-08
# 2           -33358        -48043          27        30  0.150  8.928150e-08
# 3              393        -53695          44        49  0.245  2.224380e-07
# 4            25913        -21659          77        97  0.515  3.906530e-11
# ..             ...           ...         ...       ...    ...           ...
# 73          293638       -192599          34        38  0.190  4.332870e-12
# 74            7191        -17396          59        76  0.380  9.992820e-07
# 75           21111         20872          48        56  0.720  8.475800e-09
# 76           13517         -7464          22        23  0.115  1.572250e-07
# 77           -7860        -19593          53        66  0.330  7.159920e-11
#
#        slope  slope_se  pval_perm     pval_beta  rank
# 0   0.251938  0.033759     0.0002  1.537490e-04     1
# 1   0.227727  0.031840     0.0004  2.657090e-04     1
# 2  -0.249172  0.035608     0.0003  4.218170e-04     1
# 3  -0.263364  0.039529     0.0005  5.125790e-04     1
# 4   0.262378  0.026061     0.0001  2.280810e-07     1
# ..       ...       ...        ...           ...   ...
# 73  0.232538  0.021060     0.0001  5.311140e-08     1
# 74 -0.184267  0.030112     0.0022  2.320560e-03     1
# 75 -0.228758  0.029017     0.0002  4.817430e-05     1
# 76  0.312845  0.046078     0.0005  7.624510e-04     1
# 77 -0.222933  0.022728     0.0001  6.094420e-07     1
#
# [78 rows x 18 columns]

# %%
indep_df.to_csv(test_path, sep='\t', index=False, compression='gzip')

# %%
indep_df = pd.read_csv(test_path, sep='\t')
indep_df
# Out:
#                                          phenotype_id  num_var  beta_shape1  \
# 0           ENSG00000011021.21_ENSG00000177000.10_pc1     7528      1.02539
# 1   ENSG00000083444.16_ENSG00000116685.15_ENSG0000...     7956      1.02453
# 2            ENSG00000183386.9_ENSG00000183431.11_pc1     6660      1.01822
# 3           ENSG00000117480.15_ENSG00000117481.10_pc1     5821      1.00798
# 4   ENSG00000160781.15_ENSG00000163472.18_ENSG0000...     5525      1.05451
# ..                                                ...      ...          ...
# 73          ENSG00000106772.17_ENSG00000187210.12_pc1     9842      1.05721
# 74           ENSG00000106804.7_ENSG00000119397.16_pc1     5765      1.01279
# 75          ENSG00000095321.16_ENSG00000119383.19_pc1     6663      1.01419
# 76          ENSG00000136816.15_ENSG00000136827.11_pc1     7867      1.03160
# 77           ENSG00000148296.6_ENSG00000148297.15_pc1     9211      1.05068
#
#     beta_shape2  true_df  pval_true_df              variant_id  \
# 0       836.356  25.9425  2.309540e-07   chr1_11775398_T_G_b38
# 1       916.125  26.4946  3.569540e-07   chr1_12008884_T_C_b38
# 2       815.814  26.1994  5.989100e-07   chr1_37957563_C_A_b38
# 3       360.489  25.9260  1.515300e-06   chr1_46340570_G_T_b38
# 4       500.668  25.6738  1.027350e-09  chr1_156274030_C_T_b38
# ..          ...      ...           ...                     ...
# 73     1247.880  26.1187  1.079060e-10  chr9_76713488_TG_T_b38
# 74      492.456  26.1258  5.121330e-06  chr9_121057467_A_C_b38
# 75      769.826  26.2909  7.234550e-08  chr9_129132061_A_C_b38
# 76     1008.060  26.2581  9.553980e-07  chr9_129816670_G_A_b38
# 77     1226.280  26.3984  1.012320e-09  chr9_133328538_A_G_b38
#
#     start_distance  end_distance  ma_samples  ma_count     af  pval_nominal  \
# 0           -31522        -31733          25        28  0.140  2.562980e-08
# 1            82456        -10582          60        70  0.650  5.881850e-08
# 2           -33358        -48043          27        30  0.150  8.928150e-08
# 3              393        -53695          44        49  0.245  2.224380e-07
# 4            25913        -21659          77        97  0.515  3.906530e-11
# ..             ...           ...         ...       ...    ...           ...
# 73          293638       -192599          34        38  0.190  4.332870e-12
# 74            7191        -17396          59        76  0.380  9.992820e-07
# 75           21111         20872          48        56  0.720  8.475800e-09
# 76           13517         -7464          22        23  0.115  1.572250e-07
# 77           -7860        -19593          53        66  0.330  7.159920e-11
#
#        slope  slope_se  pval_perm     pval_beta  rank
# 0   0.251938  0.033759     0.0002  1.537490e-04     1
# 1   0.227727  0.031840     0.0004  2.657090e-04     1
# 2  -0.249172  0.035608     0.0003  4.218170e-04     1
# 3  -0.263364  0.039529     0.0005  5.125790e-04     1
# 4   0.262378  0.026061     0.0001  2.280810e-07     1
# ..       ...       ...        ...           ...   ...
# 73  0.232538  0.021060     0.0001  5.311140e-08     1
# 74 -0.184267  0.030112     0.0022  2.320560e-03     1
# 75 -0.228758  0.029017     0.0002  4.817430e-05     1
# 76  0.312845  0.046078     0.0005  7.624510e-04     1
# 77 -0.222933  0.022728     0.0001  6.094420e-07     1
#
# [78 rows x 18 columns]

# %%
indep_df
# Out:
#                                          phenotype_id  num_var  beta_shape1  \
# 0           ENSG00000011021.21_ENSG00000177000.10_pc1     7528      1.02539
# 1   ENSG00000083444.16_ENSG00000116685.15_ENSG0000...     7956      1.02453
# 2            ENSG00000183386.9_ENSG00000183431.11_pc1     6660      1.01822
# 3           ENSG00000117480.15_ENSG00000117481.10_pc1     5821      1.00798
# 4   ENSG00000160781.15_ENSG00000163472.18_ENSG0000...     5525      1.05451
# ..                                                ...      ...          ...
# 73          ENSG00000106772.17_ENSG00000187210.12_pc1     9842      1.05721
# 74           ENSG00000106804.7_ENSG00000119397.16_pc1     5765      1.01279
# 75          ENSG00000095321.16_ENSG00000119383.19_pc1     6663      1.01419
# 76          ENSG00000136816.15_ENSG00000136827.11_pc1     7867      1.03160
# 77           ENSG00000148296.6_ENSG00000148297.15_pc1     9211      1.05068
#
#     beta_shape2  true_df  pval_true_df              variant_id  \
# 0       836.356  25.9425  2.309540e-07   chr1_11775398_T_G_b38
# 1       916.125  26.4946  3.569540e-07   chr1_12008884_T_C_b38
# 2       815.814  26.1994  5.989100e-07   chr1_37957563_C_A_b38
# 3       360.489  25.9260  1.515300e-06   chr1_46340570_G_T_b38
# 4       500.668  25.6738  1.027350e-09  chr1_156274030_C_T_b38
# ..          ...      ...           ...                     ...
# 73     1247.880  26.1187  1.079060e-10  chr9_76713488_TG_T_b38
# 74      492.456  26.1258  5.121330e-06  chr9_121057467_A_C_b38
# 75      769.826  26.2909  7.234550e-08  chr9_129132061_A_C_b38
# 76     1008.060  26.2581  9.553980e-07  chr9_129816670_G_A_b38
# 77     1226.280  26.3984  1.012320e-09  chr9_133328538_A_G_b38
#
#     start_distance  end_distance  ma_samples  ma_count     af  pval_nominal  \
# 0           -31522        -31733          25        28  0.140  2.562980e-08
# 1            82456        -10582          60        70  0.650  5.881850e-08
# 2           -33358        -48043          27        30  0.150  8.928150e-08
# 3              393        -53695          44        49  0.245  2.224380e-07
# 4            25913        -21659          77        97  0.515  3.906530e-11
# ..             ...           ...         ...       ...    ...           ...
# 73          293638       -192599          34        38  0.190  4.332870e-12
# 74            7191        -17396          59        76  0.380  9.992820e-07
# 75           21111         20872          48        56  0.720  8.475800e-09
# 76           13517         -7464          22        23  0.115  1.572250e-07
# 77           -7860        -19593          53        66  0.330  7.159920e-11
#
#        slope  slope_se  pval_perm     pval_beta  rank
# 0   0.251938  0.033759     0.0002  1.537490e-04     1
# 1   0.227727  0.031840     0.0004  2.657090e-04     1
# 2  -0.249172  0.035608     0.0003  4.218170e-04     1
# 3  -0.263364  0.039529     0.0005  5.125790e-04     1
# 4   0.262378  0.026061     0.0001  2.280810e-07     1
# ..       ...       ...        ...           ...   ...
# 73  0.232538  0.021060     0.0001  5.311140e-08     1
# 74 -0.184267  0.030112     0.0022  2.320560e-03     1
# 75 -0.228758  0.029017     0.0002  4.817430e-05     1
# 76  0.312845  0.046078     0.0005  7.624510e-04     1
# 77 -0.222933  0.022728     0.0001  6.094420e-07     1
#
# [78 rows x 18 columns]

# %%
indep_df_pc1
# Out:
#                                          phenotype_id  num_var  beta_shape1  \
# 0           ENSG00000011021.21_ENSG00000177000.10_pc1     7528      1.02539
# 1   ENSG00000083444.16_ENSG00000116685.15_ENSG0000...     7956      1.02453
# 2            ENSG00000183386.9_ENSG00000183431.11_pc1     6660      1.01822
# 3           ENSG00000117480.15_ENSG00000117481.10_pc1     5821      1.00798
# 4   ENSG00000160781.15_ENSG00000163472.18_ENSG0000...     5525      1.05451
# ..                                                ...      ...          ...
# 73          ENSG00000106772.17_ENSG00000187210.12_pc1     9842      1.05721
# 74           ENSG00000106804.7_ENSG00000119397.16_pc1     5765      1.01279
# 75          ENSG00000095321.16_ENSG00000119383.19_pc1     6663      1.01419
# 76          ENSG00000136816.15_ENSG00000136827.11_pc1     7867      1.03160
# 77           ENSG00000148296.6_ENSG00000148297.15_pc1     9211      1.05068
#
#     beta_shape2    true_df  pval_true_df              variant_id  \
# 0    836.356018  25.942499  2.309540e-07   chr1_11775398_T_G_b38
# 1    916.125000  26.494600  3.569540e-07   chr1_12008884_T_C_b38
# 2    815.814026  26.199400  5.989100e-07   chr1_37957563_C_A_b38
# 3    360.489014  25.926001  1.515300e-06   chr1_46340570_G_T_b38
# 4    500.667999  25.673800  1.027350e-09  chr1_156274030_C_T_b38
# ..          ...        ...           ...                     ...
# 73  1247.880005  26.118700  1.079060e-10  chr9_76713488_TG_T_b38
# 74   492.455994  26.125799  5.121330e-06  chr9_121057467_A_C_b38
# 75   769.825989  26.290899  7.234550e-08  chr9_129132061_A_C_b38
# 76  1008.059998  26.258101  9.553980e-07  chr9_129816670_G_A_b38
# 77  1226.280029  26.398399  1.012320e-09  chr9_133328538_A_G_b38
#
#     start_distance  end_distance  ma_samples  ma_count     af  pval_nominal  \
# 0           -31522        -31733          25        28  0.140  2.562980e-08
# 1            82456        -10582          60        70  0.650  5.881850e-08
# 2           -33358        -48043          27        30  0.150  8.928150e-08
# 3              393        -53695          44        49  0.245  2.224380e-07
# 4            25913        -21659          77        97  0.515  3.906530e-11
# ..             ...           ...         ...       ...    ...           ...
# 73          293638       -192599          34        38  0.190  4.332870e-12
# 74            7191        -17396          59        76  0.380  9.992820e-07
# 75           21111         20872          48        56  0.720  8.475800e-09
# 76           13517         -7464          22        23  0.115  1.572250e-07
# 77           -7860        -19593          53        66  0.330  7.159920e-11
#
#        slope  slope_se  pval_perm     pval_beta  rank
# 0   0.251938  0.033759     0.0002  1.537490e-04     1
# 1   0.227727  0.031840     0.0004  2.657090e-04     1
# 2  -0.249172  0.035608     0.0003  4.218170e-04     1
# 3  -0.263364  0.039529     0.0005  5.125790e-04     1
# 4   0.262378  0.026061     0.0001  2.280810e-07     1
# ..       ...       ...        ...           ...   ...
# 73  0.232538  0.021060     0.0001  5.311140e-08     1
# 74 -0.184267  0.030112     0.0022  2.320560e-03     1
# 75 -0.228758  0.029017     0.0002  4.817430e-05     1
# 76  0.312845  0.046078     0.0005  7.624510e-04     1
# 77 -0.222933  0.022728     0.0001  6.094420e-07     1
#
# [78 rows x 18 columns]

# %% [markdown]
# ### run eqtl analysis

# %%
expression_bed = f'/home/klawren/oak/pcqtls/data/processed/normalized_expression_proteincoding/{tissue_id}.v8.normalized_expression.bed'
pd.read_csv(expression_bed, sep='\t')
# Out:
#        #chr      start        end             gene_id  GTEX-111YS  GTEX-1122O  \
# 0      chr1     959308     959309  ENSG00000188976.10    0.251033   -1.317177
# 1      chr1     960586     960587  ENSG00000187961.13   -0.740467   -1.929642
# 2      chr1     966496     966497  ENSG00000187583.10   -0.538598   -2.007378
# 3      chr1     982092     982093   ENSG00000187642.9   -0.227967   -1.135099
# 4      chr1    1000171    1000172  ENSG00000188290.10   -0.725805   -0.024284
# ...     ...        ...        ...                 ...         ...         ...
# 14577  chrX  155458671  155458672   ENSG00000277150.1   -0.140549    1.802066
# 14578  chrX  155669943  155669944  ENSG00000185973.10    0.251033    1.047038
# 14579  chrX  155767811  155767812  ENSG00000168939.11    0.682720    2.099561
# 14580  chrX  155881292  155881293  ENSG00000124333.15    0.560321    0.730675
# 14581  chrX  155997580  155997581  ENSG00000124334.17   -1.021528   -1.047038
#
#        GTEX-1128S  GTEX-113IC  GTEX-113JC  GTEX-117XS  ...  GTEX-ZV7C  \
# 0       -0.117946    0.057935   -0.305403    1.391960  ...  -0.470701
# 1        1.034199    0.293681    0.205021    0.065421  ...  -1.610437
# 2        1.783434    1.883649    0.400858   -1.344343  ...   0.159439
# 3        0.755291    0.978416    0.654690    1.308334  ...  -0.437569
# 4        0.099157    1.475458    1.596922    0.352728  ...  -0.413033
# ...           ...         ...         ...         ...  ...        ...
# 14577   -1.344343   -1.344343   -1.344343   -1.344343  ...  -0.046713
# 14578   -0.891654   -1.453624   -0.061677   -0.654690  ...   0.591185
# 14579   -0.305403   -0.258751   -0.659325   -1.698472  ...   0.837370
# 14580   -0.765266    0.258751    0.500121   -1.453624  ...   1.066627
# 14581   -0.170799    0.716116   -0.110426    0.645460  ...  -0.305403
#
#        GTEX-ZVE2  GTEX-ZVP2  GTEX-ZVT2  GTEX-ZVT3  GTEX-ZVT4  GTEX-ZVZP  \
# 0      -0.564697  -0.205021  -0.919804   0.591185  -0.408968  -0.770282
# 1       1.308334  -0.449935  -1.120983   0.613579   0.254890  -1.034199
# 2       1.128013  -0.413033  -2.036215  -0.775318   2.259617  -0.133007
# 3       0.960486   0.110426  -0.504359   1.335178   2.368016   0.197397
# 4       0.470701  -0.046713  -0.765266   1.186387   0.227967  -1.282401
# ...          ...        ...        ...        ...        ...        ...
# 14577   0.220305   1.821345   0.009339   0.028021  -1.344343   1.929642
# 14578   0.376684   0.360690   0.525687  -1.241002   0.133007   1.509592
# 14579   2.134683  -0.031758   1.596922  -1.186387   0.842686   1.178870
# 14580  -0.591185   1.464454   1.047038  -0.356707   0.129239   0.687444
# 14581   0.243330  -0.421183  -0.914116   0.167010  -0.282000  -1.002823
#
#        GTEX-ZVZQ  GTEX-ZXES  GTEX-ZXG5
# 0       1.249111  -0.429361   0.013075
# 1       0.627164  -0.954578   1.164031
# 2       0.521402  -0.902828   1.232973
# 3       1.344343  -0.538598  -0.613579
# 4       0.902828  -1.273946   0.504359
# ...          ...        ...        ...
# 14577  -0.251033  -0.780373   0.780373
# 14578  -0.755291  -0.050453  -0.336870
# 14579  -1.265581   0.174591   0.352728
# 14580  -0.931270   0.504359   0.278115
# 14581   1.714493   0.332919   0.388743
#
# [14582 rows x 674 columns]

# %%
# define paths to data

plink_prefix_path = '/home/klawren/oak/pcqtls/data/processed/genotypes/GTEx_Analysis_2017-06-05_v8_WholeGenomeSeq_838Indiv_Analysis_Freeze.SHAPEIT2_phased.MAF01'
expression_bed = f'/home/klawren/oak/pcqtls/data/processed/normalized_expression_proteincoding/{tissue_id}.v8.normalized_expression.bed'
covariates_file = f'/home/klawren/oak/pcqtls/data/processed/covariates_peers/{tissue_id}.v8.covariates.txt'

# load phenotypes and covariates
phenotype_df, phenotype_pos_df = tensorqtl.read_phenotype_bed(expression_bed)
covariates_df = pd.read_csv(covariates_file, sep='\t', index_col=0).T

# %%
cis_df = pd.read_csv('/home/klawren/oak/pcqtls/output/proteincoding_main/control_eqtl/Whole_Blood/Whole_Blood.v8.cluster_genes.cis_qtl.txt.gz', sep='\t')
cis_df
# Out:
#                                            phenotype_id  num_var  beta_shape1  \
# 0     ENSG00000187583.10_ENSG00000187642.9_e_ENSG000...     5274     1.014020
# 1     ENSG00000187583.10_ENSG00000187642.9_e_ENSG000...     5274     1.001600
# 2     ENSG00000187608.8_ENSG00000188157.14_e_ENSG000...     5455     1.018050
# 3     ENSG00000187608.8_ENSG00000188157.14_e_ENSG000...     5455     1.014860
# 4     ENSG00000186827.10_ENSG00000186891.13_e_ENSG00...     6125     1.016640
# ...                                                 ...      ...          ...
# 1972  ENSG00000054179.11_ENSG00000176978.13_ENSG0000...     7475     1.033860
# 1973  ENSG00000054179.11_ENSG00000176978.13_ENSG0000...     7475     0.910126
# 1974  ENSG00000054179.11_ENSG00000176978.13_ENSG0000...     7475     0.991700
# 1975  ENSG00000187609.15_ENSG00000188747.8_e_ENSG000...     5881     1.022510
# 1976  ENSG00000187609.15_ENSG00000188747.8_e_ENSG000...     5881     1.050380
#
#       beta_shape2  true_df   pval_true_df  \
# 0         728.436  516.810   2.751870e-10
# 1         712.926  513.990   9.300150e-07
# 2         554.652  474.346   6.276080e-23
# 3         671.084  499.096   4.276650e-04
# 4         818.462  515.295   4.103100e-18
# ...           ...      ...            ...
# 1972     1384.650  535.308  2.780470e-113
# 1973      398.168  391.553   2.175160e-27
# 1974     1259.290  526.091   5.841890e-14
# 1975      871.250  506.838   9.675230e-06
# 1976     1001.410  526.312   3.322250e-20
#
#                                variant_id  start_distance  end_distance  \
# 0                     chr1_961096_A_G_b38           -5401        -20997
# 1                     chr1_963087_C_T_b38           -3410        -19006
# 2                    chr1_1013490_C_G_b38           12352         -6633
# 3                    chr1_1013312_G_A_b38           12174         -6811
# 4                    chr1_1217733_G_A_b38           11042          3601
# ...                                   ...             ...           ...
# 1972  chr9_137073450_GCTCTGACCACTTC_G_b38           19405        -41727
# 1973               chr9_137078448_T_C_b38           24403        -36729
# 1974               chr9_137108049_T_C_b38           54004         -7128
# 1975            chr9_137378565_GAGA_G_b38          -44697        -44785
# 1976               chr9_137407071_G_C_b38          -16191        -16279
#
#       ma_samples  ma_count        af   pval_nominal     slope  slope_se  \
# 0             61        62  0.953731   1.034050e-11  0.037518  0.005408
# 1             54        54  0.040299   1.152540e-07 -0.032025  0.005968
# 2             85        93  0.930597   1.415000e-28  0.050574  0.004327
# 3            111       130  0.902985   1.122740e-04  0.017856  0.004592
# 4            151       161  0.120149   7.788000e-21 -0.033130  0.003409
# ...          ...       ...       ...            ...       ...       ...
# 1972         345       433  0.323134  9.574440e-127 -0.047118  0.001519
# 1973         348       438  0.326866   4.367050e-41 -0.030396  0.002096
# 1974         262       300  0.776119   1.037420e-15 -0.022094  0.002679
# 1975          51        53  0.039552   1.478270e-06  0.028653  0.005892
# 1976         430       530  0.604478   8.192030e-23 -0.023246  0.002269
#
#       pval_perm      pval_beta           qval  pval_nominal_threshold
# 0      0.000100   1.605170e-07   3.644420e-08                0.000751
# 1      0.000600   6.546360e-04   1.151700e-04                0.000753
# 2      0.000100   1.538670e-20   6.185890e-21                0.000993
# 3      0.245275   2.431400e-01   3.154390e-02                0.000817
# 4      0.000100   1.914990e-15   6.342350e-16                0.000671
# ...         ...            ...            ...                     ...
# 1972   0.000100  7.492510e-114  3.722220e-113                0.000407
# 1973   0.000100   1.304510e-22   5.718240e-23                0.001157
# 1974   0.000100   8.959780e-11   2.446960e-11                0.000420
# 1975   0.009199   7.465750e-03   1.202890e-03                0.000636
# 1976   0.000100   4.812590e-18   1.774130e-18                0.000577
#
# [1977 rows x 19 columns]

# %%
# test with just chr 21 - takes ~3 min on 16 cores with 80 Gb mem
# cis.map_cis "enerates phenotype-level summary statistics with empirical p-values, enabling calculation of genome-wide FDR"
# cis.map_nominal "summary statistics for all variant-phenotype pairs"
cis_df = cis.map_cis(genotype_df, variant_df, 
                    phenotype_df.loc[phenotype_pos_df['chr'] == 'chr21'], 
                    phenotype_pos_df.loc[phenotype_pos_df['chr'] == 'chr21'],
                    covariates_df=covariates_df, seed=3042235018)

# compute q-value (in practice, this must be run on all genes, not a subset)
tensorqtl.calculate_qvalues(cis_df, qvalue_lambda=0.85)

cis_df.head()
# Out:
# cis-QTL mapping: empirical p-values for phenotypes
#   * 670 samples
#   * 214 phenotypes
#   * 68 covariates
#   * 10770860 variants
#   * cis-window: ±1,000,000
#   * using seed 3042235018
#   * checking phenotypes: 214/214
#   * computing permutations
#     processing phenotype 214/214
#   Time elapsed: 2.91 min
# done.

# %%
cis_df.to_csv('/home/klawren/oak/coexp_eqtl/output/2_eqtl_control/Whole_Blood/Whole_Blood.all_genes.permutation_qtl.chr21.txt')

# %%
prefix='/home/klawren/oak/coexp_eqtl/output/2_eqtl_control/Whole_Blood/Whole_Blood.all_genes'
cis.map_nominal(genotype_df, variant_df,
                phenotype_df.loc[phenotype_pos_df['chr'] == 'chr21'], 
                phenotype_pos_df.loc[phenotype_pos_df['chr'] == 'chr21'],
                prefix, covariates_df=covariates_df)
# Out:
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 670 samples
#   * 214 phenotypes
#   * 68 covariates
#   * 10770860 variants
#   * cis-window: ±1,000,000
#   * checking phenotypes: 214/214
#   * Computing associations
#     Mapping chromosome chr21
#     processing phenotype 214/214
#     time elapsed: 0.47 min
#     * writing output
# done.

# %%
# load results
pairs_df = pd.read_parquet(f'{prefix}.cis_qtl_pairs.chr21.parquet')
pairs_df['variant_pos'] = pairs_df['variant_id'].str.split('_').str[1].astype(int)
pairs_df.head()
# Out:
#         phenotype_id             variant_id  start_distance        af  \
# 0  ENSG00000277117.4  chr21_5031194_G_A_b38            8701  0.014179
# 1  ENSG00000277117.4  chr21_5032028_C_T_b38            9535  0.014179
# 2  ENSG00000277117.4  chr21_5033666_G_A_b38           11173  0.022388
# 3  ENSG00000277117.4  chr21_5033887_G_A_b38           11394  0.012438
# 4  ENSG00000277117.4  chr21_5035921_G_A_b38           13428  0.029851
#
#    ma_samples  ma_count  pval_nominal     slope  slope_se
# 0          18        19      0.893744 -0.026103  0.195344
# 1          18        19      0.893744 -0.026103  0.195344
# 2          26        30      0.374568  0.120248  0.135321
# 3          15        15      0.010535  0.539198  0.210147
# 4          30        40      0.894605 -0.015393  0.116140

# %%
# susie finemapping 
susie_summary, susie_res = tensorqtl.susie.map(genotype_df, variant_df, 
                    phenotype_df.loc[phenotype_pos_df['chr'] == 'chr21'], 
                    phenotype_pos_df.loc[phenotype_pos_df['chr'] == 'chr21'],
                    covariates_df, 
                    summary_only=False)
# Out:
# SuSiE fine-mapping
#   * 670 samples
#   * 214 phenotypes
#   * 68 covariates
#   * 10770860 variants
#   * cis-window: ±1,000,000
#   * checking phenotypes: 214/214
#   * fine-mapping
#     processing phenotype 214/214
#   Time elapsed: 3.74 min
# done.

# %%
susie_summary
# Out:
#             phenotype_id              variant_id       pip        af cs_id
# 0      ENSG00000277117.4   chr21_5097921_C_T_b38  0.606088  0.117164     1
# 1      ENSG00000277117.4   chr21_5099575_G_A_b38  0.380534  0.120149     1
# 2      ENSG00000280071.3   chr21_5097921_C_T_b38  0.998296  0.117164     1
# 3      ENSG00000280071.3   chr21_5089937_T_C_b38  1.000000  0.017910     2
# 4      ENSG00000275464.4   chr21_5097921_C_T_b38  0.656923  0.117164     1
# ...                  ...                     ...       ...       ...   ...
# 1539  ENSG00000160310.17  chr21_46628114_A_G_b38  0.049679  0.389552     2
# 1540  ENSG00000160310.17  chr21_46629048_G_T_b38  0.023702  0.609702     2
# 1541  ENSG00000160310.17  chr21_46629251_A_G_b38  0.023702  0.609702     2
# 1542  ENSG00000160310.17  chr21_46629323_A_G_b38  0.023702  0.609702     2
# 1543  ENSG00000160310.17  chr21_46669100_C_A_b38  0.995650  0.126119     3
#
# [1544 rows x 5 columns]

# %%
susie_res['ENSG00000280071.3'].keys()
# Out:
# dict_keys(['pip', 'sets', 'converged', 'elbo', 'niter', 'lbf_variable'])

# %%
susie_res['ENSG00000280071.3']['lbf_variable']
# Out:
# array([[-2.09897017e+00, -2.09897017e+00, -7.78277040e-01,
#         -2.20169282e+00, -1.91504848e+00, -1.31725311e+00,
#         -2.13961554e+00, -1.96829498e+00, -1.88477468e+00,
#         -1.88477480e+00, -2.20155239e+00, -1.34135222e+00,
#         -1.50151575e+00, -6.88284755e-01,  1.01212847e+00,
#         -2.20215082e+00, -1.98871505e+00,  3.82288284e+01,
#         -2.19526196e+00, -1.47842515e+00, -2.10519552e+00,
#         -2.10959768e+00, -1.73093069e+00, -6.60779834e-01,
#         -3.36158156e-01, -2.14142346e+00, -1.26939237e+00,
#          6.87035322e-02, -1.41759849e+00, -1.79048705e+00,
#         -2.04789305e+00, -2.19292307e+00, -2.09789538e+00,
#         -1.65335846e+00, -2.14280438e+00, -1.11748707e+00,
#         -2.14112377e+00, -1.24807298e+00, -2.15541220e+00,
#         -2.00251532e+00, -2.20252132e+00,  3.24564648e+00,
#          6.50459647e-01, -1.40550506e+00, -1.15163457e+00,
#         -1.03159916e+00, -2.04358339e+00, -4.21430230e-01,
#         -1.70599413e+00, -1.22336996e+00, -1.64378738e+00,
#         -2.36022830e-01, -1.66650975e+00, -2.19491053e+00,
#         -2.04810643e+00, -5.47547340e-01,  2.42405176e-01,
#         -2.04715061e+00, -7.25905418e-01, -2.06834030e+00,
#         -1.31703949e+00, -2.13978529e+00, -8.73051167e-01,
#         -8.18150759e-01, -2.66798258e-01, -2.14498949e+00,
#         -1.68062651e+00, -8.18150759e-01, -1.19319379e+00,
#         -8.18150759e-01, -1.20520759e+00, -1.94601119e+00,
#         -8.18150759e-01, -8.07889700e-01, -2.20202065e+00,
#         -8.18150759e-01, -1.96670771e+00, -2.16372180e+00,
#         -1.33695078e+00, -1.23217678e+00, -4.63033676e-01,
#         -1.75698364e+00, -7.90923238e-01, -1.02215064e+00,
#         -1.87312078e+00, -1.83409047e+00, -2.17583132e+00,
#         -1.36984348e+00,  1.90438628e-01, -3.94414902e-01,
#         -1.86216497e+00, -9.08787847e-01, -2.03230858e+00,
#         -4.94388342e-01, -7.02452540e-01, -1.60439479e+00,
#         -2.04377222e+00, -1.25843668e+00, -1.05876565e-01,
#         -1.60319889e+00, -1.65145230e+00, -2.06200290e+00,
#         -1.42598438e+00, -1.27407408e+00, -1.34015417e+00,
#         -2.19063997e+00, -1.62887740e+00,  1.09658957e-01,
#         -2.19533420e+00, -1.62263405e+00,  4.07208562e-01,
#          3.43874931e-01, -1.24177933e-02, -2.19506836e+00,
#         -2.06885052e+00, -1.97263873e+00, -1.81365728e+00,
#         -1.92489648e+00, -2.13245678e+00, -1.91167259e+00,
#         -1.65676343e+00, -2.19511366e+00, -1.92186356e+00,
#         -2.20034337e+00, -6.68483734e-01, -9.51350570e-01,
#         -1.98196673e+00, -1.91935778e+00, -1.85588777e+00,
#         -2.17255402e+00, -2.69289851e-01, -1.01838052e+00,
#         -2.17294621e+00, -2.18226290e+00, -5.74228048e-01,
#         -4.92099643e-01, -1.30209529e+00,  1.99434841e+00,
#         -1.17370176e+00, -1.02607536e+00,  3.39582801e-01,
#         -1.10081077e-01, -2.19000912e+00, -8.01319480e-01,
#          1.39812779e+00, -2.14895964e+00, -2.14895964e+00,
#         -1.46495211e+00, -1.48634899e+00, -1.85546529e+00,
#         -2.17073107e+00, -1.14430511e+00, -5.21552563e-01,
#         -4.19063926e-01, -1.18106961e-01, -1.19902313e+00,
#         -1.28780556e+00, -2.81682968e-01, -2.10515738e+00,
#         -6.91643119e-01, -1.99116623e+00, -1.51316023e+00,
#         -2.13397670e+00, -2.16538835e+00,  9.91164446e-02,
#         -1.61286950e-01, -1.84991121e-01, -1.86820102e+00,
#         -1.83211315e+00, -1.66845930e+00, -2.09557104e+00,
#         -2.07239532e+00, -1.89514983e+00, -1.10686910e+00,
#         -1.83477819e+00, -1.48531139e+00, -7.25028515e-02,
#         -1.94306779e+00, -9.22113180e-01, -9.22113180e-01,
#         -1.10712397e+00, -5.99838376e-01, -1.60802066e+00,
#         -2.02210450e+00, -2.06941748e+00, -2.17120266e+00,
#          9.24602628e-01, -3.80268216e-01, -1.06457174e+00,
#         -1.72860479e+00,  1.19806945e+00, -1.89835131e+00,
#         -1.57593834e+00, -2.04981303e+00, -6.13203764e-01,
#         -5.34200668e-03, -8.68550062e-01, -8.68550062e-01,
#         -1.71590483e+00, -2.20077538e+00, -6.61061883e-01,
#         -2.19438410e+00, -5.51561356e-01, -2.17519903e+00,
#         -1.36164570e+00,  1.16453886e+00, -1.16471660e+00,
#         -1.89213490e+00, -1.93077707e+00, -2.15234661e+00,
#          3.00519466e-02, -1.01102448e+00,  1.54643655e-01,
#         -2.20274830e+00,  5.05662441e-01, -1.34640646e+00,
#         -2.18103218e+00, -2.19003940e+00],
#        [-2.82370639e+00, -2.82370639e+00, -8.82407188e-01,
#          1.09561014e+01,  4.37144399e-01, -2.80611992e+00,
#         -2.22800493e-01, -1.22684288e+00, -1.65493286e+00,
#         -1.65493262e+00, -2.73769593e+00, -2.56877041e+00,
#         -2.31094408e+00, -2.34324574e+00,  1.98195291e+00,
#         -2.90208840e+00, -2.51130438e+00, -2.49034047e+00,
#          6.27838182e+00, -2.84123468e+00,  1.64291534e+02,
#          1.57918427e+02, -9.39831316e-01, -1.48677850e+00,
#          9.54852200e+00, -2.81398749e+00,  1.79292369e+00,
#         -1.97668791e-01, -2.64502811e+00, -2.61008310e+00,
#         -1.95940399e+00, -2.37044287e+00, -9.79676187e-01,
#         -2.38330960e-01, -2.87026548e+00, -8.71971071e-01,
#         -2.88788104e+00, -2.51849794e+00, -2.47969079e+00,
#         -2.55797815e+00, -2.60097575e+00,  1.69368458e+00,
#          3.83851886e-01, -2.56000423e+00,  1.69049191e+00,
#         -1.77850974e+00, -2.79664946e+00, -1.70430374e+00,
#         -2.48410034e+00,  3.14234233e+00, -1.96751976e+00,
#         -1.70707464e-01, -2.13721442e+00, -2.89646983e+00,
#         -2.67433572e+00, -2.70874619e-01, -7.40338922e-01,
#         -2.66604877e+00, -3.15468729e-01, -2.90668750e+00,
#          4.06609440e+00, -2.86589146e+00, -9.77813423e-01,
#         -1.87150717e+00, -1.71796024e+00, -2.88908148e+00,
#         -1.87663651e+00, -1.87150717e+00, -2.56193590e+00,
#         -1.87150717e+00, -2.65285015e+00,  1.16328585e+00,
#         -1.87150717e+00, -2.35151696e+00, -2.88433480e+00,
#         -1.87150717e+00, -1.87462449e+00, -2.62261391e+00,
#          3.57303929e+00, -2.01058340e+00, -2.35463619e+00,
#         -8.94889235e-01, -1.55714273e+00, -3.90743613e-02,
#         -2.54078412e+00,  5.24015367e-01, -2.51260757e+00,
#         -2.50537896e+00, -1.37031555e+00, -1.35195804e+00,
#         -2.77413177e+00, -2.65954375e+00, -2.56627750e+00,
#          3.56232047e-01, -4.90563393e-01, -2.80426192e+00,
#         -1.98359752e+00, -1.48098326e+00, -8.67889822e-01,
#          3.59414279e-01, -2.53565264e+00, -6.65427446e-02,
#         -2.87227297e+00, -1.96778226e+00, -2.37408161e+00,
#         -2.00765562e+00, -1.69974637e+00, -4.57741141e-01,
#         -1.79192340e+00, -2.82479525e-02,  4.05557036e-01,
#          4.32636261e-01, -7.98801601e-01, -2.50851393e+00,
#         -2.48835897e+00, -2.52507496e+00, -2.48264551e+00,
#         -2.90768075e+00, -2.90711975e+00,  2.03186870e-02,
#         -2.46689439e+00, -2.30850363e+00, -2.79631138e+00,
#         -2.85041285e+00, -2.69104004e+00, -8.14480603e-01,
#         -2.22164083e+00, -2.65421200e+00, -2.66039324e+00,
#         -1.46946502e+00, -6.82577014e-01, -1.89138007e+00,
#         -2.90026569e+00, -2.82961822e+00, -1.69369006e+00,
#         -2.28447151e+00, -2.16394043e+00,  1.58613133e+00,
#         -1.26571441e+00, -1.49602222e+00, -1.15688992e+00,
#         -1.36864018e+00, -1.49655068e+00, -1.70805895e+00,
#         -6.98072314e-02, -2.63866711e+00, -2.63866711e+00,
#         -2.66779685e+00, -2.25171661e+00, -7.83566654e-01,
#         -1.75302911e+00, -2.46185350e+00,  3.10744786e+00,
#         -1.21333480e+00, -5.29478133e-01, -1.30527472e+00,
#         -1.79451323e+00, -6.65409982e-01, -2.17267156e+00,
#         -2.24203014e+00, -2.63958764e+00, -2.53367519e+00,
#         -2.82368565e+00, -2.84058428e+00,  4.15284991e-01,
#         -1.21120358e+00, -1.02660346e+00, -2.90695810e+00,
#         -2.24302316e+00, -2.00462103e+00, -2.83447599e+00,
#         -1.81742144e+00, -2.34932780e+00, -2.59665728e-01,
#         -1.65636218e+00, -1.85299206e+00, -4.56305623e-01,
#         -2.42355537e+00, -2.17201543e+00, -2.17201543e+00,
#         -2.16553640e+00, -1.02001357e+00, -2.45156097e+00,
#         -2.57580519e+00, -2.63893342e+00, -2.90455818e+00,
#          1.98180556e-01, -2.16461992e+00, -5.07947266e-01,
#         -2.36169386e+00, -9.87497747e-01, -2.54831672e+00,
#         -2.24714279e+00, -2.88082814e+00, -6.92110538e-01,
#         -3.53176832e-01, -1.71548617e+00, -1.71548569e+00,
#         -2.51891255e+00, -2.78496003e+00, -1.34155869e+00,
#         -1.42126536e+00, -1.06133986e+00, -2.90742922e+00,
#         -1.12217236e+00, -5.13246000e-01, -2.34514165e+00,
#         -2.88230205e+00,  2.31433511e-02, -2.69801712e+00,
#         -2.90563202e+00,  2.07289100e-01, -1.96881211e+00,
#         -2.22220898e+00, -6.35802150e-02, -2.10527086e+00,
#         -2.86430120e+00, -2.89957523e+00]], dtype=float32)

# %%
pd.DataFrame(susie_res['ENSG00000277117.4'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pd.DataFrame(susie_res['ENSG00000277117.4'])
#
# File ~/micromamba/envs/tensorqtl_r/lib/python3.8/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~/micromamba/envs/tensorqtl_r/lib/python3.8/site-packages/pandas/core/internals/construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/micromamba/envs/tensorqtl_r/lib/python3.8/site-packages/pandas/core/internals/construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File ~/micromamba/envs/tensorqtl_r/lib/python3.8/site-packages/pandas/core/internals/construction.py:642, in _extract_index(data)
#     640         raw_lengths.append(len(val))
#     641     elif isinstance(val, np.ndarray) and val.ndim > 1:
# --> 642         raise ValueError("Per-column arrays must each be 1-dimensional")
#     644 if not indexes and not raw_lengths:
#     645     raise ValueError("If using all scalar values, you must pass an index")
#
# ValueError: Per-column arrays must each be 1-dimensional

# %% [markdown]
# ### data vis and sanity checks

# %%
# check the number of rows is as we'd expect
print(sum(cis_df['num_var']))
pairs_df.shape
# Out:
# 1606110
# (1606110, 9)

# %%
# q-q plot for p value inflation
f, ax = plt.subplots(figsize=(7, 7))
ax.axline((1, 1), slope=1, ls="--", c=".3")

ax.set(yscale="log", xscale="log")
stats.probplot(pairs_df['pval_nominal'], dist="uniform", plot=ax)
ax.invert_xaxis()
ax.invert_yaxis()

# change the line colors and styles
ax.get_lines()[1].set_marker('o')
ax.get_lines()[1].set_markersize(1.0)
ax.get_lines()[1].set_markeredgecolor(sns.color_palette()[0])
ax.get_lines()[2].set_linewidth(0)

ax.set_xlabel('Expected -log10(p)')
ax.set_ylabel('Observed -log10(p)')
ax.set_title('Q-Q plot for chr 21 eqtl control')
plt.show()

# %% [markdown]
# ### Plots for individual genes

# %%
# q-q plot for p value inflation for just one gene
i=2

f, ax = plt.subplots(figsize=(7, 7))
ax.axline((1, 1), slope=1, ls="--", c=".3")

ax.set(yscale="log", xscale="log")
sub_df=pairs_df[pairs_df['phenotype_id']==pairs_df['phenotype_id'].unique()[i]]
stats.probplot(sub_df['pval_nominal'], dist="uniform", plot=ax)
ax.invert_xaxis()
ax.invert_yaxis()

# change the line colors and styles
ax.get_lines()[1].set_marker('o')
ax.get_lines()[1].set_markersize(1.0)
ax.get_lines()[1].set_markeredgecolor(sns.color_palette()[0])
ax.get_lines()[2].set_linewidth(0)

ax.set_xlabel('Expected -log10(p)')
ax.set_ylabel('Observed -log10(p)')
ax.set_title('Q-Q plot for {}'.format(pairs_df['phenotype_id'].unique()[i]))
plt.show()

# %%
f, ax = plt.subplots(figsize=(7, 7))
ax.set(yscale="log")
i=3
sns.scatterplot(pairs_df[pairs_df['phenotype_id']==pairs_df['phenotype_id'].unique()[i]], x='start_distance', y='pval_nominal', ax=ax)
ax.set_title('variant associations for {}'.format(pairs_df['phenotype_id'].unique()[i]))
# Out:
# Text(0.5, 1.0, 'variant associations for ENSG00000280433.1')

# %%
f, ax = plt.subplots(figsize=(7, 7))
ax.set(yscale="log")
i=4
sns.scatterplot(pairs_df[pairs_df['phenotype_id']==pairs_df['phenotype_id'].unique()[i]], x='variant_pos', y='pval_nominal', ax=ax)
ax.set_title('variant associations for {}'.format(pairs_df['phenotype_id'].unique()[i]))
# Out:
# Text(0.5, 1.0, 'variant associations for ENSG00000275993.2')

# %%
sns.scatterplot(pairs_df[pairs_df['phenotype_id']==pairs_df['phenotype_id'].unique()[4]], x='variant_pos', y='start_distance')
# Out:
# <Axes: xlabel='variant_pos', ylabel='start_distance'>

# %% [markdown]
# ### varying sample size
# one of the figures is the num eqtl vs sample size for pcs compared to standard single gene

# %%
# get the number of independnet eqtls
indep_df = cis.map_independent(genotype_df, variant_df, cis_df,
                               phenotype_df, phenotype_pos_df, covariates_df)
# Out:
# cis-QTL mapping: conditionally independent variants
#   * 670 samples
#   * 149/214 significant phenotypes
#   * 68 covariates
#   * 10770860 variants
#   * cis-window: ±1,000,000
#   * checking phenotypes: 149/149
#   * computing independent QTLs
#     processing phenotype 149/149
#   Time elapsed: 8.75 min
# done.

# %%
indep_df.to_csv('/home/klawren/oak/coexp_eqtl/output/2_eqtl_control/Whole_Blood/Whole_Blood.all_genes.indep_qtl.chr21.txt')

# %%
indep_df.shape
# Out:
# (321, 18)

# %%
num_samples = phenotype_df.shape[1]
sub_samples = np.asarray([.1, .3, .5, 1]) * num_samples
sub_samples
# Out:
# array([ 67., 201., 335., 670.])

# %%
# change the sample sizes and run a loop

# load in a subset of the data, indexed by sample id
sub_ids = pd.Series(phenotype_df.columns.values).sample(100, random_state=26).values

# phenotype_df and genotype_df both have to be subsampled
# do the covariates need to be recalcuated??
# phenotype_pos_df, variant_df just have indexing information and can stay the same

# run the permutation step
sub_cis_df = cis.map_cis(genotype_df[sub_ids], variant_df, 
                    phenotype_df.loc[phenotype_pos_df['chr'] == 'chr21'][sub_ids], 
                    phenotype_pos_df.loc[phenotype_pos_df['chr'] == 'chr21'],
                    covariates_df=covariates_df.loc[sub_ids], seed=3042235018, warn_monomorphic=False)

# compute q-value (in practice, this must be run on all genes, not a subset)
# is this necessary to do?
tensorqtl.calculate_qvalues(sub_cis_df, qvalue_lambda=0.85)

sub_indep_df = cis.map_independent(genotype_df[sub_ids], variant_df, sub_cis_df,
                               phenotype_df[sub_ids], phenotype_pos_df, covariates_df.loc[sub_ids])
# Out:
# cis-QTL mapping: empirical p-values for phenotypes
#   * 100 samples
#   * 214 phenotypes
#   * 68 covariates
#   * 10770860 variants
#   * cis-window: ±1,000,000
#   * using seed 3042235018
#   * checking phenotypes: 214/214
#   * computing permutations
#     processing phenotype 214/214
#   Time elapsed: 1.32 min
# done.
# Computing q-values
#   * Number of phenotypes tested: 214
#   * Correlation between Beta-approximated and empirical p-values: 0.9999
#   * Calculating q-values with lambda = 0.850
#   * Proportion of significant phenotypes (1-pi0): 0.31
#   * QTL phenotypes @ FDR 0.05: 12
#   * min p-value threshold @ FDR 0.05: 0.00504157
# cis-QTL mapping: conditionally independent variants
#   * 100 samples
#   * 12/214 significant phenotypes
#   * 68 covariates
#   * 10770860 variants
#   * cis-window: ±1,000,000
#   * checking phenotypes: 12/12
#   * computing independent QTLs
#     processing phenotype 12/12
#   Time elapsed: 0.10 min
# done.

# %%
sub_indep_df.shape
# Out:
# (12, 18)
