# %% [markdown]
# ## Subsampling analysis
#
# subsample the number of inidvidualas/RNA-seq datasets and look at how number of signals changes

# %%
import pandas as pd
import numpy as np
import os
import yaml
import seaborn as sns
import matplotlib.pyplot as plt
import ast

import holoviews as hv
hv.extension('bokeh')

import upsetplot as up
from tqdm.auto import tqdm  # for notebooks
tqdm.pandas()


prefix = '/home/klawren/oak/pcqtls'

import sys
sys.path.append('/home/klawren/oak/pcqtls/workflow/scripts')
from notebook_helper_functions import *
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %% [markdown]
# I then run snakemake on each sumsample made with 'make_subsamples.ipynb' to get QTLs with config files in config/subsampling/
#
#
# this next analysis assumes results in those folders

# %%
subsample_output_folder = f'{prefix}/config/subsampling'

# %% [markdown]
# ### Number QTLs across subsamples

# %%
# load in the configs for each 

subsample_nums = [50, 75, 100, 200, 250, 300, 350, 400, 450]

sub_config = {}
for num_samples in subsample_nums:
    config_path= f'{subsample_output_folder}/{num_samples}_subsample.yaml'
    with open(config_path, 'r') as f:
        config = yaml.safe_load(f)
        sub_config[num_samples] = config


tissue_ids = load_tissue_ids(config)
tissue_df = load_tissue_df(config)
tissue_pal = sns.color_palette('blend:#B83A4B,#FEC51D,#67AFD2', n_colors=len(tissue_ids))


tissue_id = 'Cells_Cultured_fibroblasts'

# %%
# to load the random 100 (rather than 1st 100)
# for num_samples in [101]:
#     config_path= f'{prefix}/config/subsampling/{num_samples-1}_rand_subsample.yaml'
#     with open(config_path, 'r') as f:
#         config = yaml.safe_load(f)
#         sub_config[num_samples] = config

# %% [markdown]
# for some reason, there are a two different types of outputs if there are no signifignat hits. for the 50 subsample, the

# %%
pval_key = 'pval_beta'


def get_counts(config):
    counts = pd.DataFrame()
    for tissue_id in tissue_ids:
        cluster_df = load_cluster(config, tissue_id)
        counts.loc[tissue_id, 'clusters'] = len(cluster_df)
        counts.loc[tissue_id, 'cluster_genes'] = sum(cluster_df['N_genes'])

        # load eqtls and analyze
        try: 
            e_permutation_df = load_e_permutation(config, tissue_id)
            e_permutation_signifigant = e_permutation_df[e_permutation_df[pval_key] < .05]
            counts.loc[tissue_id, 'e_clusters_permutation'] = e_permutation_signifigant['cluster_id'].nunique()
            counts.loc[tissue_id, 'e_qtl_permutation'] = len(e_permutation_signifigant)
        except FileNotFoundError as e:
            print(e)
            counts.loc[tissue_id, 'e_clusters_permutation'] = 0
            counts.loc[tissue_id, 'e_qtl_permutation'] = 0

        # load pcqlts and anaylze
        try: 
            pc1_only_permutation_df = load_pc_permutation(config, tissue_id, pc1_only=True)
            pc_permutation_df = load_pc_permutation(config, tissue_id, pc1_only=False)
            pc_permutation_signifigant = pc_permutation_df[pc_permutation_df[pval_key] < .05]
            counts.loc[tissue_id, 'pc_clusters_permutation'] = pc_permutation_signifigant['cluster_id'].nunique()
            counts.loc[tissue_id, 'pc_qtl_permutation'] = len(pc_permutation_signifigant)

            pc1_only_permutation_signifigant = pc1_only_permutation_df[pc1_only_permutation_df[pval_key] < .05]
            counts.loc[tissue_id, 'pc1_clusters_permutation'] = pc1_only_permutation_signifigant['cluster_id'].nunique()
            counts.loc[tissue_id, 'pc1_qtl_permutation'] = len(pc1_only_permutation_signifigant)

        except FileNotFoundError as e:
            print(e)
            counts.loc[tissue_id, 'pc_clusters_permutation'] = 0
            counts.loc[tissue_id, 'pc_qtl_permutation'] = 0
            counts.loc[tissue_id, 'pc1_clusters_permutation'] = 0
            counts.loc[tissue_id, 'pc1_qtl_permutation'] = 0


    return counts.rename_axis('Tissue').reset_index()

# %%
sub_counts = []
for num_samples in tqdm(subsample_nums):
    sub_counts.append(get_counts(sub_config[num_samples]))
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# [Errno 2] No such file or directory: '/home/klawren/oak/pcqtls/output/subsampling_constant_clusters/50/control_eqtl//Cells_Cultured_fibroblasts/Cells_Cultured_fibroblasts.v8.cluster_genes.cis_independent_qtl.txt.gz'
# [Errno 2] No such file or directory: '/home/klawren/oak/pcqtls/output/subsampling_constant_clusters/50/pcqtl//Cells_Cultured_fibroblasts/Cells_Cultured_fibroblasts.v8.pcs.cis_independent_qtl.txt.gz'
# [Errno 2] No such file or directory: '/home/klawren/oak/pcqtls/output/subsampling_constant_clusters/50/control_eqtl//Skin_Not_Sun_Exposed_Suprapubic/Skin_Not_Sun_Exposed_Suprapubic.v8.cluster_genes.cis_independent_qtl.txt.gz'
# [Errno 2] No such file or directory: '/home/klawren/oak/pcqtls/output/subsampling_constant_clusters/50/pcqtl//Skin_Not_Sun_Exposed_Suprapubic/Skin_Not_Sun_Exposed_Suprapubic.v8.pcs.cis_independent_qtl.txt.gz'
# [Errno 2] No such file or directory: '/home/klawren/oak/pcqtls/output/subsampling_constant_clusters/50/control_eqtl//Whole_Blood/Whole_Blood.v8.cluster_genes.cis_independent_qtl.txt.gz'
# [Errno 2] No such file or directory: '/home/klawren/oak/pcqtls/output/subsampling_constant_clusters/50/pcqtl//Whole_Blood/Whole_Blood.v8.pcs.cis_independent_qtl.txt.gz'

# %%
# normalize by number cluster-genes
joined_count_df = pd.concat(sub_counts, keys=[*subsample_nums, 101], names=['num_samples', 'idx'])
joined_count_df['e_clusters_permutation_normed'] = joined_count_df['e_clusters_permutation']/joined_count_df['clusters']
joined_count_df['pc_clusters_permutation_normed'] = joined_count_df['pc_clusters_permutation']/joined_count_df['clusters']
joined_count_df['e_qtl_permutation_normed'] = joined_count_df['e_qtl_permutation']/joined_count_df['cluster_genes']
joined_count_df['pc_qtl_permutation_normed'] = joined_count_df['pc_qtl_permutation']/joined_count_df['cluster_genes']

joined_count_df.reset_index(level=0, inplace=True)
joined_counts = joined_count_df.melt(id_vars=['Tissue', 'num_samples'], var_name='count_type', value_name='count')

# %%
plot_cols = ['e_clusters_permutation_normed', 'pc_clusters_permutation_normed', 'e_qtl_permutation_normed', 'pc_qtl_permutation_normed']
joined_counts = joined_count_df[[*plot_cols, 'Tissue', 'num_samples']].melt(id_vars=['Tissue', 'num_samples'], var_name='count_type', value_name='count')

g = sns.FacetGrid(joined_counts, col="count_type", hue='Tissue', palette = tissue_pal, height=4)
g.map(sns.lineplot, "num_samples", "count")
g.map(sns.scatterplot, "num_samples", "count")
g.add_legend()
g.fig.subplots_adjust(top=0.8)
g.fig.suptitle('Subsampled counts')
# Out:
# Text(0.5, 0.98, 'Subsampled counts')

# %% [markdown]
# comparisons between tissues should be on a per/cluster-gene basis. plot the pc and e versions on the same plot

# %%
joined_counts = joined_count_df[['e_clusters_permutation_normed', 'pc_clusters_permutation_normed', 'Tissue', 'num_samples']].melt(id_vars=['Tissue', 'num_samples'], var_name='count_type', value_name='count')
joined_counts['qtl_type'] = joined_counts['count_type'].str.split('_').str[0]

fig, ax = plt.subplots(figsize=(8,5))
sns.lineplot(data = joined_counts,
             x='num_samples',
             y='count',
             style='qtl_type',
             hue='Tissue',
             palette = tissue_pal,
             marker='o',
             ax=ax)

ax.set_ylabel('fraction clusters w/ a signifigant qtl')
ax.set_xlabel('RNA-seq samples')
ax.set_ylim(0,1)
ax.set_title('Signifigant clusters vs sample size for pc and eqtls')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
joined_counts = joined_count_df[['e_qtl_permutation', 'pc_qtl_permutation', 'Tissue', 'num_samples']].melt(id_vars=['Tissue', 'num_samples'], var_name='count_type', value_name='count')
joined_counts['qtl_type'] = joined_counts['count_type'].str.split('_').str[0]

fig, ax = plt.subplots(figsize=(8,5))

sns.lineplot(data = joined_counts,
             x='num_samples',
             y='count',
             style='qtl_type',
             hue='Tissue',
             palette = tissue_pal,
             marker='o',
             ax=ax)

ax.set_ylabel('number independent signifigant qtls')
ax.set_xlabel('RNA-seq samples')
ax.set_title('Signifigant QTLs vs sample size for pc and eqtls')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %% [markdown]
# ### variant sharing

# %%
import holoviews as hv
hv.extension('bokeh')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
# get the counts for unique lead vars 
subset_counts = up.query(up.from_contents({'100':sub_overlaps[100]['lead_variant_id'].unique(),
 '200':sub_overlaps[200]['lead_variant_id'].unique()})).subset_sizes

subset_counts = pd.DataFrame(subset_counts)

subset_counts['source'] = [('' if value else 'Not ') + 'QTL w/ 100' for value in subset_counts.index.get_level_values('100')]
subset_counts['target'] = [('' if value else 'Not ') + 'QTL w/ 200' for value in subset_counts.index.get_level_values('200')]

# sort the target and source to be QTLs on the bottom, not QTLs on the top 
subset_counts['source'] = pd.Categorical(subset_counts['source'], ["QTL w/ 100", "Not QTL w/ 100"])
subset_counts['target'] = pd.Categorical(subset_counts['target'], ["QTL w/ 200", "Not QTL w/ 200"])

subset_counts.sort_values(['source', 'target'], inplace=True)

sankey = hv.Sankey(subset_counts, label='Shared lead vars 100 vs 200 subsamples', vdims='size')
sankey.opts(label_position='left', edge_color='target', cmap='tab20')
# Out:
# :Sankey   [source,target]   (size)

# %%
def get_cs_overlap(row, var_list):
    return sum(var_list.isin(row['variant_list_2'])) > 0

sub_overlaps[100]['variant_list_2'] = sub_overlaps[100]['variant_list'].apply(ast.literal_eval)
vars_100 = sub_overlaps[100]['variant_list_2'].explode()

sub_overlaps[200]['variant_list_2'] = sub_overlaps[200]['variant_list'].apply(ast.literal_eval)
vars_200 = sub_overlaps[200]['variant_list_2'].explode()

sub_overlaps[100]['200_overlap'] = sub_overlaps[100].progress_apply(get_cs_overlap, axis=1, args=(vars_200,))
sub_overlaps[200]['100_overlap'] = sub_overlaps[200].progress_apply(get_cs_overlap, axis=1, args=(vars_100,))

# %%
subset_counts.loc[(True,True), 'size'] = sum(sub_overlaps[100]['200_overlap'])
subset_counts.loc[(False,True), 'size'] = len(sub_overlaps[100]) - sum(sub_overlaps[100]['200_overlap'])
subset_counts.loc[(True,False), 'size'] = len(sub_overlaps[200]) - sum(sub_overlaps[200]['100_overlap'])

# %%
subset_counts = pd.DataFrame(subset_counts)

subset_counts['source'] = [('' if value else 'Not ') + 'part of cs w/ 100' for value in subset_counts.index.get_level_values('100')]
subset_counts['target'] = [('' if value else 'Not ') + 'part of cs w/ 200' for value in subset_counts.index.get_level_values('200')]

# sort the target and source to be QTLs on the bottom, not QTLs on the top 
subset_counts['source'] = pd.Categorical(subset_counts['source'], ["part of cs w/ 100", "Not part of cs w/ 100"])
subset_counts['target'] = pd.Categorical(subset_counts['target'], ["part of cs w/ 200", "Not part of cs w/ 200"])

subset_counts.sort_values(['source', 'target'], inplace=True)

sankey = hv.Sankey(subset_counts, label='Credible set overlap 100 vs 200 subsample', vdims='size')
sankey.opts(label_position='left', node_color='index', cmap='tab20')
# Out:
# :Sankey   [source,target]   (size)
